# %% [markdown]
# # Funktionen

# %% [markdown]
# Funktionen erlauben es uns, Programme kürzer zu machen, besser zu organisieren, leichter zu lesen und zu debuggen und besser wiederzuverwenden.
# Ein grosser Vorteil an Funktionen ist es, Bausteine erneut verwenden zu können.

# %% [markdown]
# # Beispiel

# %% [markdown]
# Ein einfaches Beispiel:

# %%
def sag_hallo():
    print("Hallo")

# %% [markdown]
# Nun ist die Funktion erstellt. (Gleich wie bei Variablen in Jupyter Notebook, müssen wir die Funktion einmal laufen lassen, damit sie gespeichert wird.) Wir können sie nun aufrufen, indem wir sag_hallo() schreiben:

# %%
sag_hallo()

# %% [markdown]
# Das praktische ist, wir können nun diese Funktion mehrfach verwenden um z.B 100 mal Hallo zu sagen:

# %%
for i in range(100):
    sag_hallo()

# %% [markdown]
# # Funktionen mit Argumenten

# %% [markdown]
# Eine Funktion mit Argumenten gibt uns die Möglichkeit einen oder mehrere Werte der Funktion zu übergeben.

# %% [markdown]
# Wir können nun z.B eine Funktion schreiben, welche überprüft ob eine Zahl x ungerade ist oder nicht. Die Variable x ist in diesem Beispiel das Argument der Funktion "gerade(x)".

# %%
def gerade(x):
    if x % 2 == 0:
        print("gerade")
    else:
        print("ungerade")

# %% [markdown]
# Testen wir diese anhand mehrerer Werte:

# %%
gerade(10)
gerade(13)
gerade(19)

# %% [markdown]
# Wir können einer Funktion auch gleich mehrere Argumente übergeben. Diese müssen allerdings alle bei der Definition der Funktion genannt werden. Die Funktion erwartet immer soviele Argumente, wie definiert sind:

# %% [markdown]
# Im nächsten Beispiel möchten wir eine Funktion schreiben, welche überprüft ob eine Variable a durch eine Variable b teilbar ist:

# %%
def teilbar(a,b):
    if a % b == 0:
        print("a ist durch b teilbar")
    else:
        print("a ist nicht durch b teilbar")

# %% [markdown]
# # Rückgabewert

# %% [markdown]
# Um eine Funktion noch cleverer einsetzen zu können, können wir Rückgabewerte verwenden.
# Beispielsweise sollen von den Zahlen von 1-100 die Zahlen ausgegeben werden, welche durch 2 teilbar sind. Wir modifizieren die Funktion "teilbar(a,b)" so, dass die Rückgabe "True" oder "False" zurückgegeben wird.

# %%
def teilbar(a,b):
    if a % b == 0:
        print("a ist durch b teilbar")
        return True
    else:
        print("a ist nicht durch b teilbar")
        return False

# %% [markdown]
# Diese Rückgabe "return True/False" können wir in einem if-Statement direkt nutzen, um die Teilbarkeit durch 2 zu prüfen.

# %%
for n in range(100):
    if teilbar(n,2) == True:
        print(n)

# %% [markdown]
# Das "return"-Statement verhält sich ähnlich wie das "break"-Statement bei den loops. Sobald es ausgeführt wird, wird die Funktion beendet und der Rückgabewert zurückgegeben.
# Wir kürzen die Funktion noch ein wenig und belassen nur die essenziellen Teile:

# %%
def teilbar(a,b):
    if a % b == 0:
        return True
    else:
        return False

# %% [markdown]
# Nun können wir lediglich die Werte zurückgeben, welche Teilbar sind durch 2:

# %%
for n in range(10):
    if teilbar(n,2) == True:
        print(n)

# %% [markdown]
# # Funktionen innerhalb Funktionen

# %% [markdown]
# Wir können innerhalb von Funktionen andere Funktionen aufrufen. Versuchen wir nun eine Funktion zu schreiben, welche uns alle geraden Zahlen bis zu einem bestimmten Wert n zurückgeben, welche durch 3 Teilbar sind.
#
# Wir definieren eine neue Funktion "teilbar_bis(n)", welche die Funktion "teilbar(a,b)" verwendet:

# %%
def teilbar_bis(n):
    for x in range(n):
        if teilbar(x,3) == True:
            print(x)
teilbar_bis(50)

# %% [markdown]
# Da der Rückgabewert der Funktion "teilbar(a,b)" bereits eine logische Aussage "True/False" ist, können wir den Code noch ein wenig vereinfachen:

# %%
def teilbar_bis(n):
    for x in range(n):
        if teilbar(x,3):  #Abkürzen
            print(x)
teilbar_bis(20)

# %% [markdown]
# ### Aufgabe 1

# %% [markdown]
# Schreibe `quadrieren(x)` (return vs. print erklären). Beispiel: x=3 → 9

# %% [markdown]
# <details><summary>Lösung</summary>
#
# ```python
# def quadrieren(x):
#     return x * x
# wert = quadrieren(3)
# print(wert)
# ```
#
# </details>

# %% [markdown]
# ### Aufgabe 2

# %% [markdown]
# Schreibe `rechteck(l, b)` (Fläche/Umfang). Beispiel: 3 x 4 → (12, 14)

# %% [markdown]
# <details><summary>Lösung</summary>
#
# ```python
# def rechteck(l, b):
#     flaeche = l * b
#     umfang = 2 * (l + b)
#     return flaeche, umfang
# print(rechteck(3, 4))
# ```
#
# </details>

# %% [markdown]
# ### Aufgabe 3

# %% [markdown]
# Schreibe `summe_zwei(a,b)` (Addition). Beispiel: 5 und 7 → 12

# %% [markdown]
# <details><summary>Lösung</summary>
#
# ```python
# def summe_zwei(a, b):
#     return a + b
# print(summe_zwei(5, 7))
# ```
#
# </details>

# %% [markdown]
# ### Aufgabe 4

# %% [markdown]
# Schreibe `max3(a,b,c)` ohne `max()`. Beispiel: (1, 9, 3) → 9

# %% [markdown]
# <details><summary>Lösung</summary>
#
# ```python
# def max3(a, b, c):
#     m = a
#     if b > m: m = b
#     if c > m: m = c
#     return m
# print(max3(1, 9, 3))
# ```
#
# </details>

# %% [markdown]
# ### Aufgabe 5

# %% [markdown]
# Schreibe `ist_prim(n)` (Primzahl nur durch 1 und sich selbst teilbar). Beispiel: 11 → True

# %% [markdown]
# <details><summary>Lösung</summary>
#
# ```python
# def ist_prim(n):
#     if n < 2:
#         return False
#     for i in range(2, int(n**0.5) + 1):
#         if n % i == 0:
#             return False
#     return True
# print(ist_prim(11), ist_prim(12))
# ```
#
# </details>

# %% [markdown]
# ### Aufgabe 6

# %% [markdown]
# Schreibe `buchstabensuche(buchstabe, wort)` (True/False). Beispiel: ('a', 'Banane') → True

# %% [markdown]
# <details><summary>Lösung</summary>
#
# ```python
# def buchstabensuche(buchstabe, wort):
#     return buchstabe in wort
# print(buchstabensuche('a', 'Banane'))
# ```
#
# </details>

# %% [markdown]
# ### Aufgabe 7

# %% [markdown]
# Schreibe `min_mit_max(x,y)` ohne `min()`. Beispiel: (3,5) → 3

# %% [markdown]
# <details><summary>Lösung</summary>
#
# ```python
# def min_mit_max(x, y):
#     return x + y - max(x, y)
# print(min_mit_max(3, 5))
# ```
#
# </details>

# %% [markdown]
# ### Aufgabe 8

# %% [markdown]
# Schreibe `durch_vier(n)`, die True zurückgibt, wenn n durch 4 teilbar ist. Beispiel: 12 → True, 10 → False.

# %% [markdown]
# <details><summary>Lösung</summary>
#
# ```python
# def durch_vier(n):
#     return n % 4 == 0
# print(durch_vier(12), durch_vier(10))
# ```
#
# </details>

# %% [markdown]
# ### Aufgabe 9

# %% [markdown]
# Schreibe einen Kreisrechner `kreis(radius)`, der Fläche, Umfang und Durchmesser liefert. Hinweis: `import math`. Beispiel: Radius 2 → (F, U, D).

# %% [markdown]
# <details><summary>Lösung</summary>
#
# ```python
# import math
# def kreis(radius):
#     flaeche = math.pi * radius * radius
#     umfang = 2 * math.pi * radius
#     durchmesser = 2 * radius
#     return flaeche, umfang, durchmesser
# print(kreis(2))
# ```
#
# </details>

# %% [markdown]
# ### Zusatzaufgabe 1

# %% [markdown]
# Teste `ist_prim(n)` mit mehreren Zahlen (z.B. 2,3,4,11,15).

# %% [markdown]
# <details><summary>Lösung</summary>
#
# ```python
# def ist_prim(n):
#     if n < 2:
#         return False
#     for i in range(2, int(n**0.5) + 1):
#         if n % i == 0:
#             return False
#     return True
# for test in [2,3,4,11,15]:
#     print(test, ist_prim(test))
# ```
#
# </details>

# %% [markdown]
# ### Zusatzaufgabe 2

# %% [markdown]
# Schreibe `c_to_f` und `f_to_c` und prüfe, ob 0°C → 32°F und umgekehrt stimmen.
#
# Formel: Celsius → Fahrenheit: f = c * 1.8 + 32; Fahrenheit → Celsius: c = (f - 32) / 1.8

# %% [markdown]
# <details><summary>Lösung</summary>
#
# ```python
# def c_to_f(c):
#     return c * 1.8 + 32
# def f_to_c(f):
#     return (f - 32) / 1.8
# print(c_to_f(0), f_to_c(32))
# ```
#
# </details>

# %% [markdown]
# ### Zusatzaufgabe 3

# %% [markdown]
# Schreibe `fak(n)` iterativ (Fakultät = Produkt 1*2*...*n).

# %% [markdown]
# <details><summary>Lösung</summary>
#
# ```python
# def fak(n):
#     ergebnis = 1
#     for i in range(1, n+1):
#         ergebnis *= i
#     return ergebnis
# print(fak(5))
# ```
#
# </details>

# %% [markdown]
# ### Zusatzaufgabe 4

# %% [markdown]
# Schreibe `summe_liste(lst)`, die alle Elemente einer Zahlenliste addiert.

# %% [markdown]
# <details><summary>Lösung</summary>
#
# ```python
# def summe_liste(lst):
#     total = 0
#     for n in lst:
#         total += n
#     return total
# print(summe_liste([1,2,3]))
# ```
#
# </details>

# %% [markdown]
# ### Zusatzaufgabe 5

# %% [markdown]
# Schreibe `ist_palindrom(wort)`, das prüft, ob ein Wort vorwärts und rückwärts gleich ist. Beispiel: 'anna' → True.

# %% [markdown]
# <details><summary>Lösung</summary>
#
# ```python
# def ist_palindrom(wort):
#     return wort == wort[::-1]
# print(ist_palindrom('anna'), ist_palindrom('test'))
# ```
#
# </details>
